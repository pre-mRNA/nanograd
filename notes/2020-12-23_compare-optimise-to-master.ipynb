# %% [markdown]
# # compare master to optimise
#
# The runtimes of the two modes are different:
#
# - master: 48s, 65s, 60s
# - optimise: consistently over 5 minutes
#
# \# revert to branch git reset --hard 9d54ca261b317ae587f1131cabd26f2c16888c3a
#
# runtime: 68s, 53s, 50s

# %% [markdown]
# # check the bam smoothing
#
# Sequin cluster 434
# Screen Shot 2020-12-24 at 3.57.50 PM![image.png](attachment:image.png)

# %% [markdown]
# # run master for mousebrain 1
#
# - Launched at 16:01
